# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Đọc dữ liệu từ file CSV
data = pd.read_csv('khaosat.csv')  # Hoặc phương pháp khác

# # Kiểm tra dữ liệu
print(data.head())
# Out:
#          Dấu thời gian Bạn đang học khoa nào? Khóa  Giới tính   Chiều cao   \
# 0  09/01/2025 16:34:56        Khoa học Cơ bản  K64         Nữ  1m55 - 1m65
# 1  09/01/2025 16:36:48    Công nghệ Thông Tin  K64        Nam  1m65 - 1m75
# 2  25/02/2025 21:55:24                 Cơ khí  K65        Nam  1m55 - 1m65
# 3  25/02/2025 22:00:11                 Cơ khí  K62        Nam  1m75 - 1m85
# 4  26/02/2025 14:50:26        Khoa học Cơ bản  K64         Nữ  1m65 - 1m75
#
#   Cân nặng (kg)   \
# 0        40 - 50
# 1        40 - 50
# 2        50 - 60
# 3        60 - 70
# 4        60 - 70
#
#   1. Trong một hoc kỳ, bạn có thường xuyên cảm thấy lo lắng, bồn chồn vì áp lực học hành và thi cử không?  \
# 0                                            Hầu như
# 1                                       Thỉnh thoảng
# 2                                              Không
# 3                                              Không
# 4                                            Hầu như
#
# ...
